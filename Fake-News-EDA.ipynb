# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
# %matplotlib inline

df = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Fake-News-EDA\fake_or_real_news.csv")

df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df.shape
# Out:
# (6335, 4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6335 entries, 0 to 6334
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6335 non-null   int64
#  1   title       6335 non-null   object
#  2   text        6335 non-null   object
#  3   label       6335 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 198.1+ KB

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0                          title  \
# count    6335.000000                           6335
# unique           NaN                           6256
# top              NaN  OnPolitics | 's politics blog
# freq             NaN                              5
# mean     5280.415627                            NaN
# std      3038.503953                            NaN
# min         2.000000                            NaN
# 25%      2674.500000                            NaN
# 50%      5271.000000                            NaN
# 75%      7901.000000                            NaN
# max     10557.000000                            NaN
#
#                                                      text label
# count                                                6335  6335
# unique                                               6060     2
# top     Killing Obama administration rules, dismantlin...  REAL
# freq                                                   58  3171
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["text_length"] = df["text"].apply(len)

# %%
df["title_length"] = df["title"].apply(len)

# %%
df["word_count"] = df["text"].apply(lambda x: len(x.split()))

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df, x='label')

plt.title("Distribution of Fake and Real News")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["word_count"], bins=40)

plt.title("Distribution of Article Word Count")

plt.xlabel("Word Count")

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(data=df, x="label", y="word_count")

plt.title("Word Count by News Type")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["title_length"], bins=30)

plt.title("Distribution of Title Length")

plt.show()

# %%
numeric_df = df[['text_length',
                 'title_length',
                 'word_count']]
plt.figure(figsize=(6,5))

sns.heatmap(numeric_df.corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.boxplot(df["word_count"])
plt.show()

Q1 = df["word_count"].quantile(0.25)

Q3 = df["word_count"].quantile(0.75)

IQR = Q3-Q1

lower = Q1-1.5*IQR

upper = Q3+1.5*IQR

outliers = df[(df["word_count"]<lower) | (df["word_count"]>upper)]

outliers.shape
# Out:
# (283, 7)

# %%
df[['text_length',
    'title_length',
    'word_count']].corr()
# Out:
#               text_length  title_length  word_count
# text_length      1.000000      0.024213    0.998138
# title_length     0.024213      1.000000    0.025165
# word_count       0.998138      0.025165    1.000000
